# %%
from threading import Thread
import os
import datetime

# %%
chatbot = "chatbot.py"
# chatbot = "mock_chatbot.py"


def run_streamlit():
    NOW = datetime.datetime.now().strftime("%Y-%m-%dT%H:%M:%S")
    os.system(f"pipenv run streamlit run ./{chatbot} --server.port 8501 > ./{NOW}.log")

# %%
# Start a thread to run the Streamlit app
thread = Thread(target=run_streamlit)
thread.start()

# You kinda have to kill the kernel to stop the thread
# ...or find the process running on this port and destroy it
#
# netstat -vanp tcp | grep 8501
# kill -9 <pid>

# %% [markdown]
# Open up a tunnel to your localhost to view the chatbot interface on a different machine. You'll need your local IP as the password to access it.

# %%
# !npm install --silent localtunnel
# Out:
# ⸨░░░░░░░░░░░░░░░░░░⸩ ⠧ rollbackFailedOptional: verb npm-session 70297ddf526509c
# Courtesy Notice: Pipenv found itself running within a virtual environment, so it will automatically use that environment, instead of creating its own for any project. You can set PIPENV_IGNORE_VIRTUALENVS=1 to force pipenv to ignore that environment and create its own instead. You can set PIPENV_VERBOSITY=-1 to suppress this warning.
# + localtunnel@2.0.2░░░░░⸩ ⠏ postinstall: info lifecycle localtunnel@2.0.2~postinstal
# updated 1 package and audited 36 packages in 0.781s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 2 moderate severity vulnerabilities
#   run `npm audit fix` to fix them, or `npm audit` for details
# 7m            ░░░░░░⸩ ⠹ postinstall: timing audit body Completed in 1ms

# %%
# !curl https://loca.lt/mytunnelpassword
# Out:
# 98.228.137.207

# %%
# !npx localtunnel --port 8501
# Out:
# ░░░░⠂⠂⠂⠂⠂⠂⸩ ⠇ build:yargs: sill linkStuff yargs@17.1.1 is installed innpx: installed 22 in 2.369s
# your url is: https://hip-dancers-reply.loca.lt
# ^C
