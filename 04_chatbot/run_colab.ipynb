# %%
# %%bash
# pip install -q \
# streamlit \
# langchain \
# langchain-community \
# sentence-transformers \
# chromadb \
# rank-bm25 \
# llama-cpp-python

# %%
# !npm install --silent localtunnel

# %%
from threading import Thread
import sys
import os
import datetime

import streamlit as st

# %%
# from google.colab import drive

# drive.mount("/content/drive", force_remount=True)

# !ls ./drive/MyDrive/Capstone/chatbot

# %%
# %%writefile ./app.py
# %%writefile ./drive/MyDrive/Capstone/chatbot/app.py

# Replace with app.py code

# %%
# %%bash
# NOW=$(date +"%Y-%m-%dT%H:%M:%S");
#
# streamlit run ./app.py --server.port 8501 > ./${NOW}.log &
# Out:
# Process is interrupted.

# %%
def run_streamlit():
    NOW = datetime.datetime.now().strftime("%Y-%m-%dT%H:%M:%S")
    os.system(f"streamlit run ./app.py --server.port 8501 > ./{NOW}.log")

# %%
# Start a thread to run the Streamlit app
thread = Thread(target=run_streamlit)
thread.start()

# You kinda have to kill the kernel to stop the thread
# Or find the process running on this port and destroy it
# netstat -vanp tcp | grep 8501
# kill -9 <pid>

# %%
# !curl https://loca.lt/mytunnelpassword
# Out:
# 98.228.137.207

# %%
# !npx localtunnel --port 8501
# Out:
# ░░░░⠂⠂⠂⠂⠂⠂⸩ ⠼ preinstall:localtunnel: timing action:refresh-package-jsnpx: installed 22 in 3.614s
# your url is: https://small-dragons-glow.loca.lt
# ^C

# %%
# from google.colab import output

# output.serve_kernel_port_as_window(8501)
